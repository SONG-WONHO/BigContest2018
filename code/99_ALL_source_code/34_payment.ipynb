# %%
# module 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset 로딩
x_load = pd.read_csv('C:\\Users\\zeus_\\Desktop\\champion_data\\test\\test_payment.csv').sort_values(by='acc_id', ascending=True)
y_load = pd.read_csv('C:\\Users\\zeus_\\Desktop\\champion_data\\train\\train_label.csv').sort_values(by='acc_id', ascending=True)['label']

# %%
x_data = x_load
y_data = y_load

# %%
#횟수 데이터 복원
x_data.loc[:,'payment_amount'] = (x_data.loc[:,'payment_amount'] - x_data.loc[:,'payment_amount'].min())/(x_data.loc[:, 'payment_amount'][x_data.loc[:, 'payment_amount'] > x_data.loc[:,'payment_amount'].min()].min() - x_data.loc[:,'payment_amount'].min())*33

# %%
x_temp = x_data[x_data['payment_week'] == 1].drop(['payment_week', 'payment_amount'], axis=1)

# %%
x_temp
# Out:
#                                                    acc_id
# 0       0002a56a036206aea3a6c6ebc985df4a2d1987b562e7f0...
# 8       0003bfdebe2b5d46217e8fa5ab0f33cf186fb558435f20...
# 16      0008f5dce798aaac3f0b05f8a4269cf2052c9b8c5bd911...
# 24      000cacd86bddabebef813351455304df5493cd71a3d1d2...
# 32      000ef0765596ac6a6a0a62654895e4673825b6102c7f41...
# 40      0013b91d3408e3bfa7d7b88a0ec49b2fb1cedc4677d9e7...
# 48      0015a0e5bd1bdd2a539a6e7387baa2b12576a685f21d1b...
# 56      0018858b7f1b9941fd957ead27b3abf97ae1bc21627f0b...
# 64      001fb818efb64b03b6017990997ab0033665159ba6f485...
# 72      002005ac069dc0614e87def718023dd0b6cddac93d5393...
# 80      0020b7efba9cf5a0299e18ddc69b09c8aa0c49c0067265...
# 88      0020cfd12e09c70f20bc2387ed8946ab0363ed66670c81...
# 96      00214f2b044baffaac29eef31795b1111010e5234d27bd...
# 104     0023e287809a212b21ba17557783d6176e28db4ec065e3...
# 112     0026a38cbf9bc322d6a88ec90a568583555d16656f2d72...
# ...

# %%
for i in range(1,9):
    x_temp['payment_amount_' + str(i)] = x_data[x_data['payment_week'] == i].payment_amount.values

# %%
x_temp
# Out:
#                                                    acc_id  payment_amount_1  \
# 0       0002a56a036206aea3a6c6ebc985df4a2d1987b562e7f0...          0.000000
# 8       0003bfdebe2b5d46217e8fa5ab0f33cf186fb558435f20...          0.000000
# 16      0008f5dce798aaac3f0b05f8a4269cf2052c9b8c5bd911...          0.000000
# 24      000cacd86bddabebef813351455304df5493cd71a3d1d2...          0.000000
# 32      000ef0765596ac6a6a0a62654895e4673825b6102c7f41...          0.000000
# 40      0013b91d3408e3bfa7d7b88a0ec49b2fb1cedc4677d9e7...          0.000000
# 48      0015a0e5bd1bdd2a539a6e7387baa2b12576a685f21d1b...          0.000000
# 56      0018858b7f1b9941fd957ead27b3abf97ae1bc21627f0b...          0.000000
# 64      001fb818efb64b03b6017990997ab0033665159ba6f485...          0.000000
# 72      002005ac069dc0614e87def718023dd0b6cddac93d5393...          0.000000
# 80      0020b7efba9cf5a0299e18ddc69b09c8aa0c49c0067265...          0.000000
# ...

# %%
x_temp.to_csv('C:\\Users\\zeus_\\Desktop\\champion_data\\test\\test_payment_week.csv')

# %%
x = x_data.groupby('acc_id').sum().payment_amount

# %%
x = pd.concat([x.to_frame(), x_data.groupby('acc_id').mean().payment_amount], axis=1)

# %%
x = pd.concat([x, x_data.groupby('acc_id').mean().payment_amount > 0], axis=1)

# %%
x.columns = ['payment_amount_sum', 'payment_amount_mean', 'payment_amount_bool']

# %%
x.payment_amount_bool = x.apply(lambda v: 1 if v.payment_amount_bool == True else 0, axis = 1)

# %%
x.to_csv('C:\\Users\\zeus_\\Desktop\\champion_data\\test\\test_payment_post.csv')
